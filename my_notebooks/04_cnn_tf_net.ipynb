# %% [markdown]
# #### LeNet-5 Inspired Network

# %% [markdown]
# Imports

# %%
import tensorflow
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout, BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten

# %% [markdown]
# Load Data

# %%
(X_train, y_train), (X_valid, y_valid) = mnist.load_data()

# %% [markdown]
# Preprocess Data

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %%
X_train = X_train.reshape(60000,28,28,1).astype('float32')
X_valid=X_valid.reshape(10000,28,28,1).astype('float32')

# %%
X_train /= 255
X_valid /= 255

# %%
n_class = 10
y_train = to_categorical(y_train,n_class)
y_valid = to_categorical(y_valid,n_class)

# %% [markdown]
# Model Architecture

# %%
model = Sequential()

model.add(Conv2D(32, kernel_size=(3,3), activation='relu', input_shape=(28,28,1)))
# "*for keras, by default, strides is (1,1), padding is 'valid' (not using padding)

model.add(Conv2D(64, kernel_size=(3,3), activation='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))
model.add(Flatten())

model.add(Dense(128,activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(10, activation='softmax'))
# Out:
# c:\Users\keztan\workspace\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 24, 24, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 12, 12, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 12, 12, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 9216)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     1,179,776 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,199,882 (4.58 MB)
#  Trainable params: 1,199,882 (4.58 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Config Model

# %%
model.compile(loss='categorical_crossentropy', optimizer='nadam',metrics=['accuracy'])

# %% [markdown]
# Train Model

# %%
model.fit(X_train,y_train,batch_size=128,epochs=10,verbose=1,validation_data=(X_valid,y_valid))
# Out:
# Epoch 1/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 39s 78ms/step - accuracy: 0.8503 - loss: 0.4754 - val_accuracy: 0.9815 - val_loss: 0.0563
# Epoch 2/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 37s 80ms/step - accuracy: 0.9729 - loss: 0.0916 - val_accuracy: 0.9878 - val_loss: 0.0363
# Epoch 3/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 39s 83ms/step - accuracy: 0.9819 - loss: 0.0614 - val_accuracy: 0.9876 - val_loss: 0.0356
# Epoch 4/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 39s 83ms/step - accuracy: 0.9847 - loss: 0.0495 - val_accuracy: 0.9892 - val_loss: 0.0301
# Epoch 5/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 39s 82ms/step - accuracy: 0.9864 - loss: 0.0428 - val_accuracy: 0.9911 - val_loss: 0.0287
# Epoch 6/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 38s 82ms/step - accuracy: 0.9884 - loss: 0.0370 - val_accuracy: 0.9918 - val_loss: 0.0256
# Epoch 7/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 40s 86ms/step - accuracy: 0.9898 - loss: 0.0318 - val_accuracy: 0.9924 - val_loss: 0.0273
# Epoch 8/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 39s 84ms/step - accuracy: 0.9903 - loss: 0.0284 - val_accuracy: 0.9917 - val_loss: 0.0285
# Epoch 9/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 39s 83ms/step - accuracy: 0.9919 - loss: 0.0258 - val_accuracy: 0.9917 - val_loss: 0.0307
# Epoch 10/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 39s 83ms/step - accuracy: 0.9933 - loss: 0.0218 - val_accuracy: 0.9920 - val_loss: 0.0285
